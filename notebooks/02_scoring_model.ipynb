# %%
#Accessibility
import pandas as pd
df["accessibility"] = (
    0.6 * df["metro_access"] +
    0.4 * df["road_connectivity"]
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 #Accessibility
#       2 df["accessibility"] = (
# ----> 3     0.6 * df["metro_access"] +
#       4     0.4 * df["road_connectivity"]
#       5 )
#
# NameError: name 'df' is not defined
